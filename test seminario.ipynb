# %%
import requests
response = requests.get('https://community-api.coinmetrics.io/v4/catalog/market-orderbooks?pretty=true&api_key=<your_key>').json()

print(response)
# Out:
# {'data': [{'market': 'binance-1000LUNCBUSD-future', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1000SHIBBUSD-future', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1000SHIBUSDT-future', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1000XECUSDT-future', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1INCHUSDT-future', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1inch-btc-spot', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1inch-busd-spot', 'min_time': '2022-07-28T23:46:25.000000000Z', 'max_time': '2022-07-29T23:00:00.000000000Z'}, {'market': 'binance-1inch-usdt-spot', 'min_time': '2022-
# ...

# %%
import requests
import datetime as dt
import json

print(valor)
# Out:
# {'price': 1722.27, 'currency': 'usd', 'date': '2022-07-30T10:22:06.335882'}

# %%
a
# Out:
# {'date': '2022-07-29T21:25:33.703415'}

# %%
response['ethereum']['usd']
# Out:
# 1731.83

# %%
value_serializer=lambda valor: json.dumps(valor).encode('utf-8')

# %%
value_serializer
# Out:
# <function __main__.<lambda>(valor)>

# %%
from random import randrange, random
from datetime import datetime, timedelta
from time import sleep
import requests
import json
import sys
response = requests.get('https://api.coingecko.com/api/v3/simple/price?ids=ethereum&vs_currencies=usd').json()
a=str(datetime.now().isoformat())
crypto_data={}
crypto_data['date']=a
crypto_data['price']=response['ethereum']['usd']
crypto_data['currency']='usd'

# %%
a
# Out:
# '2022-07-31T20:39:09.747495'
